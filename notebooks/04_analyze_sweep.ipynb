# %% [markdown]
# Analyze and visualize results of Optuna sweep

# %%
import optuna

study = optuna.load_study(study_name="chip_stroma_v1", storage="sqlite:///optuna_v1.db")

importances = optuna.importance.get_param_importances(study)  # fANOVA (Hutter et al., 2014)
print(importances)  # only fix params below ~5% relative importance
